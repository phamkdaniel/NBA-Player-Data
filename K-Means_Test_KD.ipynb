# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
nba_data = pd.read_csv('Data/nba_data.csv')
nba_data.head()
# Out:
#    Unnamed: 0             player pos  age team_id   g  gs    mp   fg   fga  \
# 0           0       Alex Abrines  SG   25     OKC  31   2   588   56   157
# 1           2       Jaylen Adams  PG   22     ATL  34   1   428   38   110
# 2           3       Steven Adams   C   25     OKC  80  80  2669  481   809
# 3           4        Bam Adebayo   C   21     MIA  82  28  1913  280   486
# 4           7  LaMarcus Aldridge   C   33     SAS  81  81  2687  684  1319
#
#    ...  tov_pct  usg_pct  ows  dws   ws  ws_per_48  obpm  dbpm  bpm  vorp
# 0  ...      7.9     12.2  0.1  0.6  0.6      0.053  -2.4  -0.9 -3.4  -0.2
# 1  ...     19.7     13.5 -0.1  0.2  0.1      0.011  -3.1  -1.3 -4.4  -0.3
# 2  ...     12.6     16.4  5.1  4.0  9.1      0.163   0.6   2.1  2.7   3.2
# 3  ...     17.1     15.8  3.4  3.4  6.8      0.171  -0.6   3.6  3.0   2.4
# 4  ...      8.8     26.9  6.4  2.9  9.3      0.167   1.2   0.5  1.6   2.5
#
# [5 rows x 104 columns]

# %%
# nba_data = nba_data.set_index('rank')

# %%
test_data = nba_data.drop(['Unnamed: 0', 'player', 'pos', 'team_id'], axis=1, inplace=True)

# %%
nba_data.head()
# Out:
#    age   g  gs    mp   fg   fga  fg_pct  fg3  fg3a  fg3_pct  ...  tov_pct  \
# 0   25  31   2   588   56   157   0.357   41   127    0.323  ...      7.9
# 1   22  34   1   428   38   110   0.345   25    74    0.338  ...     19.7
# 2   25  80  80  2669  481   809   0.595    0     2    0.000  ...     12.6
# 3   21  82  28  1913  280   486   0.576    3    15    0.200  ...     17.1
# 4   33  81  81  2687  684  1319   0.519   10    42    0.238  ...      8.8
#
#    usg_pct  ows  dws   ws  ws_per_48  obpm  dbpm  bpm  vorp
# 0     12.2  0.1  0.6  0.6      0.053  -2.4  -0.9 -3.4  -0.2
# 1     13.5 -0.1  0.2  0.1      0.011  -3.1  -1.3 -4.4  -0.3
# 2     16.4  5.1  4.0  9.1      0.163   0.6   2.1  2.7   3.2
# 3     15.8  3.4  3.4  6.8      0.171  -0.6   3.6  3.0   2.4
# 4     26.9  6.4  2.9  9.3      0.167   1.2   0.5  1.6   2.5
#
# [5 rows x 100 columns]

# %%
nototals_df = nba_data.drop(['mp', 'fg', 'fga', 'fg3', 'fg3a', 'fg2', 'fg2a', 'ft', 'fta', 'ft_pct', 'orb', 'drb', 'trb',\
                              'ast', 'stl', 'blk', 'tov', 'pf', 'pts'], axis=1)
metrics_df = nba_data[['ows', 'dws', 'ws', 'ws_per_48', 'obpm', 'dbpm', 'bpm', 'vorp']]
offprofile_df = nba_data[['fg_pct', 'fg3_pct', 'fg2_pct', 'efg_pct', 'ft_pct','ts_pct', 'fg3a_per_fga_pct', 
                           'fta_per_fga_pct', 'fg_per_poss', 'fga_per_poss', 'fg3_per_poss', 'fg3a_per_poss', 
                          'fg2_per_poss', 'fg2a_per_poss', 'ft_per_poss', 'fta_per_poss', 'ast_per_poss', 'pts_per_poss', 
                          'usg_pct']]

# %%
# Plot and show scatter
# plt.scatter(X[:, 0], X[:, 1])
# plt.show()

# %%
# Create a kmeans model using k = 12
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=5)

# Fit the model to the data
kmeans.fit(nba_data)

# Use the data to predict the clusters
# save the predictions as `predicted_clusters`
# predicted_clusters = kmeans.predict(X)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=5, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
#plt.scatter(X[:, 0], X[:, 1], c=predicted_clusters, s=50, cmap='viridis')
#plt.show()

# %%
# Print the cluster centers and cluster labels
centers = kmeans.cluster_centers_
labels = kmeans.labels_

# %%
centers
# Out:
# array([[ 2.63358779e+01,  3.87480916e+01,  5.47328244e+00,
#          5.32175573e+02,  6.99923664e+01,  1.60687023e+02,
#          4.39740458e-01,  2.01984733e+01,  6.17786260e+01,
#          2.79419847e-01,  4.97938931e+01,  9.89083969e+01,
#          4.98328244e-01,  5.00198473e-01,  2.80763359e+01,
#          3.92595420e+01,  7.17274809e-01,  2.49541985e+01,
#          7.60534351e+01,  1.01007634e+02,  4.36488550e+01,
#          1.52595420e+01,  1.11374046e+01,  2.54045802e+01,
#          5.54809160e+01,  1.88259542e+02,  1.41900763e+01,
#          1.89465649e+00,  4.37862595e+00,  5.53435115e-01,
#          1.68854962e+00,  1.34198473e+00,  2.68778626e+00,
#          7.73282443e-01,  1.08244275e+00,  6.42748092e-01,
#          2.00534351e+00,  2.64961832e+00,  1.15496183e+00,
#          4.19847328e-01,  2.92366412e-01,  6.84732824e-01,
#          1.48244275e+00,  5.11984733e+00,  4.79083969e+00,
#          1.09816794e+01,  1.35572519e+00,  4.16412214e+00,
# ...

# %%
# plt.scatter(X[:, 0], X[:, 1], c=labels, s=50, cmap='viridis')
#plt.scatter(centers[:, 0], centers[:, 1], c='black', s=200, alpha=0.5)

# plt.show()
